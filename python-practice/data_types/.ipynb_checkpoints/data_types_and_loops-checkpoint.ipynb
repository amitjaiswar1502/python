# %% [markdown]
# ### markdown for the datatype ####

# %% [markdown]
# ### revenue for 3 quarters ###

# %%
revenues = [56 ,60 ,80]
expenses = [20,40,30]
margin_percentage = []

for  i in range(len(revenues)):
    profits = revenues[i] - expenses[i]
    margins = profits * 100/revenues[i]
   
    margin_percentage.append(margins.2f)
    print(f"Margin percentage = {margin_percentage}")
# Out:
# Margin percentage = [64.28571428571429]
# Margin percentage = [64.28571428571429, 33.333333333333336]
# Margin percentage = [64.28571428571429, 33.333333333333336, 62.5]

# %%
print(margin) 
type(margin)
food_description = ("""Hello I like vadapav  .
It is very delicious dish""")
type(food_description)
print(food_description)
len(food_description)
# Out:
# 140.0
# Hello I like vadapav  .
# It is very delicious dish
# 49
